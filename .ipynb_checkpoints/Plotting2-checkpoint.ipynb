# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

# load in file from Rot3_data folder using pickle
pickle_in = open("Rot3_data\\Rat_full_df.pkl","rb")
Animal_df = pickle.load(pickle_in)
Animal_df = Animal_df.sort_index()  # sort according to index, this should sort according to date

# %%
sfo = plt.figure()
ax1 = sfo.add_subplot(2,2,1)
ax2 = sfo.add_subplot(2,2,2)
ax3 = sfo.add_subplot(2,2,3)

from numpy.random import randn
plt.plot(randn(50).cumsum(),'k--')
_ = ax1.hist(randn(100), bins=20, color = 'k', alpha=0.3)
ax2.scatter(np.arange(30),np.arange(30) +3 * randn(30))

sfo, axes = plt.subplots(2,3)
axes
#sharex and sharey can make figures have the same axis
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000024A0C390>,
# ...
#       dtype=object)

# %%
Animal_df.plot(subplots=True)

# %%
fig2 = Animal_df['done_trials'].plot(ylim=[0,10])
